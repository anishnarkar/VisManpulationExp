# %%
import h5py

# %%
filename = 'C:/Users/anark/Downloads/public_code-20220827T220741Z-001/public_code/Datasets/h5/combinedSyntheticDataset_293.h5'
h5 = h5py.File(filename,'r')

# %%
h5.keys()
# Out:
# <KeysViewHDF5 ['float_pupil_x', 'float_pupil_y', 'float_pupilellipse_angle', 'float_pupilellipse_major', 'float_pupilellipse_minor', 'images']>

# %%
image_data = h5['images']
position_x = h5['float_pupil_x']
position_y = h5['float_pupil_y']
float_pupilellipse_angle = h5['float_pupilellipse_angle']
float_pupilellipse_major =h5['float_pupilellipse_major']
float_pupilellipse_minor = h5['float_pupilellipse_minor']

# %%
image_data.shape, position_x.shape, position_x.shape,float_pupilellipse_angle.shape,float_pupilellipse_major.shape
# Out:
# ((2400, 1, 1, 1, 293, 293), (2400,), (2400,), (2400,), (2400,))

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image_data[5,0,0,0])
plt.scatter(x=position_x[5], y=position_y[5])
plt.scatter(x=position_x[5],y=position_y[5])

# %%
float_pupilellipse_major[5]
# Out:
# 21.86008
